# %% [markdown]
# # EgoExo Manifest Generator
#
# Generates a set of EgoExo manifest files from the given directory (s3 or local) using smart defaults.
#
# Set the variables in the cell below, and run all. This will output manifest files to `<OUTPUT_DIRECTORY>/manifest_<MANIFEST_VERSION>/`.
#
# The following files are generated:
# - take_metadata.csv
# - video_metadata.csv
# - video_component_file.csv
#
# NOTE: It is **safe** to modify manifest files after generation and re-run.
# This notebook will retain existing rows, and only add new ones that didn't exist.
#
# ### Pre-requisites:
# - Jupyter kernel with boto3 and pandas installed
# - You have run `aws configure` and set up your AWS keys
# - (Highly recommended) Recorded files are already uploaded to s3
# - ROOT_DIR has the structure: `<ROOT_DIR>/<take_id>/(ego|exo)/<camera_id>/<video files>`

# %%
ROOT_DIR = "s3://ego4d-university-sa/data/"
WALKAROUND_CAM_NAMES = ["mobile"]
EGO_HAS_WALKAROUND = True # True if Ego Cameras all have walkarounds (this should be the case)
OUTPUT_DIRECTORY = "/Users/dkukreja/Downloads/test-manifests/"
MANIFEST_VERSION = "v1"

# %%
# Imports
import os
import boto3
import pandas as pd

# %%
# Utilities
s3 = boto3.resource("s3")

def is_s3_path(path):
    return path.startswith('s3://')

def split_s3_path(s3_path):
    path_parts = s3_path.strip().replace("s3://", "").split("/")
    bucket = path_parts.pop(0)
    key = "/".join(path_parts)
    return bucket, key

def ls(path):
    if is_s3_path(path):
        bucket, key = split_s3_path(path)
        if not key.endswith("/"):
            key = key + "/"
        keys = [x.key for x in s3.Bucket(bucket).objects.filter(Prefix=key)]
        return list(set([x.replace(key, '').split('/')[0] for x in keys]))
    if os.path.isfile(path):
        return None
    return [f for f in os.listdir(path)]

def is_video(path):
    filename = os.path.basename(path)
    return filename.lower().endswith(".mp4") or filename.lower().endswith(".vrs")

# %% [markdown]
# ## Generate take_metadata.csv

# %%
take_ids = ls(ROOT_DIR)
take_ids
# Out:
# ['003_bouldering',
#  '001_dance',
#  '002_dance',
#  '001_bouldering',
#  '003_dance',
#  '002_bouldering']

# %%
clean_take_ids = [
    x for x in take_ids if len(set(['ego', 'exo']).intersection(set(ls(os.path.join(ROOT_DIR, x))))) > 0
]
clean_take_ids
# Out:
# ['003_bouldering',
#  '001_dance',
#  '002_dance',
#  '001_bouldering',
#  '003_dance',
#  '002_bouldering']

# %%
take_metadata_records = []
for take_id in clean_take_ids:
    root = os.path.join(ROOT_DIR, take_id)
    root_ls = ls(root)
    ego_cameras = (
        ls(os.path.join(root, "ego")) if "ego" in root_ls else []
    )
    exo_cameras = (
        ls(os.path.join(root, "exo")) if "exo" in root_ls else []
    )

    video_count = 0
    for cam in ego_cameras:
        video_count += len(
            [x for x in ls(os.path.join(root, "ego", cam)) if is_video(x)]
        )
    for cam in exo_cameras:
        video_count += len(
            [x for x in ls(os.path.join(root, "exo", cam)) if is_video(x)]
        )

    take_metadata_records.append(
        {
            "university_take_id": take_id,
            "university_video_folder_path": os.path.join(ROOT_DIR, take_id) if is_s3_path(ROOT_DIR) else "s3://please-upload-me",
            "number_videos": video_count,
            "recording_participant_id": None,
            "physical_setting_id": None,
            "video_scenario_ids": None,
        }
    )

take_metadata = pd.DataFrame.from_records(take_metadata_records)
take_metadata
# Out:
#   university_take_id                  university_video_folder_path  \
# 0     003_bouldering  s3://ego4d-university-sa/data/003_bouldering
# 1          001_dance       s3://ego4d-university-sa/data/001_dance
# 2          002_dance       s3://ego4d-university-sa/data/002_dance
# 3     001_bouldering  s3://ego4d-university-sa/data/001_bouldering
# 4          003_dance       s3://ego4d-university-sa/data/003_dance
# 5     002_bouldering  s3://ego4d-university-sa/data/002_bouldering
#
#    number_videos recording_participant_id physical_setting_id  \
# 0             10                     None                None
# 1             10                     None                None
# 2              6                     None                None
# 3             10                     None                None
# 4              7                     None                None
# 5              7                     None                None
#
#   video_scenario_ids
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# 5               None

# %% [markdown]
# ## Generate video_metadata.csv

# %%
video_metadata_records = []
for take_id in clean_take_ids:
    root = os.path.join(ROOT_DIR, take_id)
    root_ls = ls(root)
    ego_cameras = (
        ls(os.path.join(root, "ego")) if "ego" in root_ls else []
    )
    exo_cameras = (
        ls(os.path.join(root, "exo")) if "exo" in root_ls else []
    )

    video_count = 0
    for cam in ego_cameras:
        cam_root = os.path.join(root, "ego", cam)
        video_metadata_records.append(
            {
                "university_take_id": take_id,
                "university_video_id": cam,
                "number_video_components": len(
                    [x for x in ls(cam_root) if is_video(x)]
                ),
                "is_ego": True,
                "has_walkaround": EGO_HAS_WALKAROUND,
                "is_redacted": False,
                "includes_audio": True,
                "device_id": cam,
                "recording_participant_id": None,
                "video_device_settings": None,
            }
        )

    for cam in exo_cameras:
        cam_root = os.path.join(root, "exo", cam)
        video_metadata_records.append(
            {
                "university_take_id": take_id,
                "university_video_id": cam,
                "number_video_components": len(
                    [x for x in ls(cam_root) if is_video(x)]
                ),
                "is_ego": False,
                "has_walkaround": cam in WALKAROUND_CAM_NAMES,
                "is_redacted": False,
                "includes_audio": True,
                "device_id": cam,
                "recording_participant_id": None,
                "video_device_settings": None,
            }
        )
        
    # Remove any 'cameras' with 0 videos. This removes extraneous files like .DS_STORE
    video_metadata_records = [x for x in video_metadata_records if x['number_video_components'] > 0]

video_metadata = pd.DataFrame.from_records(video_metadata_records)
video_metadata
# Out:
#    university_take_id university_video_id  number_video_components  is_ego  \
# 0      003_bouldering              aria01                        1    True
# 1      003_bouldering               cam03                        2   False
# 2      003_bouldering               cam04                        2   False
# 3      003_bouldering              mobile                        1   False
# 4      003_bouldering               cam01                        2   False
# 5      003_bouldering               cam02                        2   False
# 6           001_dance              aria01                        1    True
# 7           001_dance               cam03                        2   False
# 8           001_dance               cam04                        2   False
# 9           001_dance              mobile                        1   False
# 10          001_dance               cam01                        2   False
# 11          001_dance               cam02                        2   False
# 12          002_dance              aria01                        1    True
# 13          002_dance               cam03                        1   False
# 14          002_dance               cam04                        1   False
# 15          002_dance              mobile                        1   False
# 16          002_dance               cam01                        1   False
# 17          002_dance               cam02                        1   False
# 18     001_bouldering              aria01                        1    True
# 19     001_bouldering               cam03                        2   False
# 20     001_bouldering               cam04                        2   False
# 21     001_bouldering              mobile                        1   False
# 22     001_bouldering               cam01                        2   False
# 23     001_bouldering               cam02                        2   False
# 24          003_dance              aria01                        1    True
# 25          003_dance               cam03                        1   False
# 26          003_dance               cam04                        1   False
# 27          003_dance              mobile                        1   False
# 28          003_dance               cam01                        2   False
# 29          003_dance               cam02                        1   False
# 30     002_bouldering              aria01                        1    True
# 31     002_bouldering               cam03                        1   False
# 32     002_bouldering               cam04                        1   False
# 33     002_bouldering              mobile                        2   False
# 34     002_bouldering               cam01                        1   False
# 35     002_bouldering               cam02                        1   False
#
#     has_walkaround  is_redacted  includes_audio device_id  \
# 0             True        False            True    aria01
# 1            False        False            True     cam03
# 2            False        False            True     cam04
# 3             True        False            True    mobile
# 4            False        False            True     cam01
# 5            False        False            True     cam02
# 6             True        False            True    aria01
# 7            False        False            True     cam03
# 8            False        False            True     cam04
# 9             True        False            True    mobile
# 10           False        False            True     cam01
# 11           False        False            True     cam02
# 12            True        False            True    aria01
# 13           False        False            True     cam03
# 14           False        False            True     cam04
# 15            True        False            True    mobile
# 16           False        False            True     cam01
# 17           False        False            True     cam02
# 18            True        False            True    aria01
# 19           False        False            True     cam03
# 20           False        False            True     cam04
# 21            True        False            True    mobile
# 22           False        False            True     cam01
# 23           False        False            True     cam02
# 24            True        False            True    aria01
# 25           False        False            True     cam03
# 26           False        False            True     cam04
# 27            True        False            True    mobile
# 28           False        False            True     cam01
# 29           False        False            True     cam02
# 30            True        False            True    aria01
# 31           False        False            True     cam03
# 32           False        False            True     cam04
# 33            True        False            True    mobile
# 34           False        False            True     cam01
# 35           False        False            True     cam02
#
#    recording_participant_id video_device_settings
# 0                      None                  None
# 1                      None                  None
# 2                      None                  None
# 3                      None                  None
# 4                      None                  None
# 5                      None                  None
# 6                      None                  None
# 7                      None                  None
# 8                      None                  None
# 9                      None                  None
# 10                     None                  None
# 11                     None                  None
# 12                     None                  None
# 13                     None                  None
# 14                     None                  None
# 15                     None                  None
# 16                     None                  None
# 17                     None                  None
# 18                     None                  None
# 19                     None                  None
# 20                     None                  None
# 21                     None                  None
# 22                     None                  None
# 23                     None                  None
# 24                     None                  None
# 25                     None                  None
# 26                     None                  None
# 27                     None                  None
# 28                     None                  None
# 29                     None                  None
# 30                     None                  None
# 31                     None                  None
# 32                     None                  None
# 33                     None                  None
# 34                     None                  None
# 35                     None                  None

# %% [markdown]
# ## Generate video_component_file.csv

# %%
video_component_file_records = []
for take_id in clean_take_ids:
    root = os.path.join(ROOT_DIR, take_id)
    root_ls = ls(root)
    ego_cameras = (
        ls(os.path.join(root, "ego")) if "ego" in root_ls else []
    )
    exo_cameras = (
        ls(os.path.join(root, "exo")) if "exo" in root_ls else []
    )

    video_count = 0
    for cam in ego_cameras:
        cam_root = os.path.join(root, "ego", cam)
        for i, filename in enumerate(
            sorted([x for x in ls(cam_root) if is_video(x)])
        ):
            video_component_file_records.append(
                {
                    "university_take_id": take_id,
                    "university_video_id": cam,
                    "video_component_relative_path": f"ego/{cam}/{filename}",
                    "component_index": i,
                    "is_redacted": False,
                    "component_metadata": None,
                    "deidentification_metadata": None,
                }
            )

    for cam in exo_cameras:
        cam_root = os.path.join(root, "exo", cam)
        for i, filename in enumerate(
            sorted([x for x in ls(cam_root) if is_video(x)])
        ):
            video_component_file_records.append(
                {
                    "university_take_id": take_id,
                    "university_video_id": cam,
                    "video_component_relative_path": f"exo/{cam}/{filename}",
                    "component_index": i,
                    "is_redacted": False,
                    "component_metadata": None,
                    "deidentification_metadata": None,
                }
            )

video_component_file = pd.DataFrame.from_records(video_component_file_records)
video_component_file
# Out:
#    university_take_id university_video_id  \
# 0      003_bouldering              aria01
# 1      003_bouldering               cam03
# 2      003_bouldering               cam03
# 3      003_bouldering               cam04
# 4      003_bouldering               cam04
# 5      003_bouldering              mobile
# 6      003_bouldering               cam01
# 7      003_bouldering               cam01
# 8      003_bouldering               cam02
# 9      003_bouldering               cam02
# 10          001_dance              aria01
# 11          001_dance               cam03
# 12          001_dance               cam03
# 13          001_dance               cam04
# 14          001_dance               cam04
# 15          001_dance              mobile
# 16          001_dance               cam01
# 17          001_dance               cam01
# 18          001_dance               cam02
# 19          001_dance               cam02
# 20          002_dance              aria01
# 21          002_dance               cam03
# 22          002_dance               cam04
# 23          002_dance              mobile
# 24          002_dance               cam01
# 25          002_dance               cam02
# 26     001_bouldering              aria01
# 27     001_bouldering               cam03
# 28     001_bouldering               cam03
# 29     001_bouldering               cam04
# 30     001_bouldering               cam04
# 31     001_bouldering              mobile
# 32     001_bouldering               cam01
# 33     001_bouldering               cam01
# 34     001_bouldering               cam02
# 35     001_bouldering               cam02
# 36          003_dance              aria01
# 37          003_dance               cam03
# 38          003_dance               cam04
# 39          003_dance              mobile
# 40          003_dance               cam01
# 41          003_dance               cam01
# 42          003_dance               cam02
# 43     002_bouldering              aria01
# 44     002_bouldering               cam03
# 45     002_bouldering               cam04
# 46     002_bouldering              mobile
# 47     002_bouldering              mobile
# 48     002_bouldering               cam01
# 49     002_bouldering               cam02
#
#                         video_component_relative_path  component_index  \
# 0   ego/aria01/73988cc8-04b6-4a77-899c-ab3e9a85ad1...                0
# 1                              exo/cam03/GX010084.MP4                0
# 2                              exo/cam03/GX020084.MP4                1
# 3                              exo/cam04/GX010055.MP4                0
# 4                              exo/cam04/GX020055.MP4                1
# 5                             exo/mobile/GX010046.MP4                0
# 6                              exo/cam01/GX010047.MP4                0
# 7                              exo/cam01/GX020047.MP4                1
# 8                              exo/cam02/GX010064.MP4                0
# 9                              exo/cam02/GX020064.MP4                1
# 10  ego/aria01/4dc2bc31-aa8c-43f6-8081-32c5e205725...                0
# 11                             exo/cam03/GX010048.MP4                0
# 12                             exo/cam03/GX020048.MP4                1
# 13                             exo/cam04/GX010085.MP4                0
# 14                             exo/cam04/GX020085.MP4                1
# 15                            exo/mobile/GX010058.MP4                0
# 16                             exo/cam01/GX010059.MP4                0
# 17                             exo/cam01/GX020059.MP4                1
# 18                             exo/cam02/GX010256.MP4                0
# 19                             exo/cam02/GX020256.MP4                1
# 20  ego/aria01/1eb61103-86fc-4ec8-80c9-38a5379557b...                0
# 21                             exo/cam03/GX010049.MP4                0
# 22                             exo/cam04/GX010086.MP4                0
# 23                            exo/mobile/GX010058.MP4                0
# 24                             exo/cam01/GX010060.MP4                0
# 25                             exo/cam02/GX010257.MP4                0
# 26                               ego/aria01/video.vrs                0
# 27                             exo/cam03/GX010083.MP4                0
# 28                             exo/cam03/GX020083.MP4                1
# 29                             exo/cam04/GX010054.MP4                0
# 30                             exo/cam04/GX020054.MP4                1
# 31                            exo/mobile/GX010042.MP4                0
# 32                             exo/cam01/GX010045.MP4                0
# 33                             exo/cam01/GX020045.MP4                1
# 34                             exo/cam02/GX010063.MP4                0
# 35                             exo/cam02/GX020063.MP4                1
# 36  ego/aria01/7edcc694-64f2-4656-9aa6-a4fa592d281...                0
# 37                             exo/cam03/GX010050.MP4                0
# 38                             exo/cam04/GX010087.MP4                0
# 39                            exo/mobile/GX010058.MP4                0
# 40                           exo/cam01/._GX010061.MP4                0
# 41                             exo/cam01/GX010061.MP4                1
# 42                             exo/cam02/GX010258.MP4                0
# 43  ego/aria01/9f502597-2821-4bba-80f3-f486606f2ba...                0
# 44                             exo/cam03/GX010082.MP4                0
# 45                             exo/cam04/GX010053.MP4                0
# 46                          exo/mobile/._GX010044.MP4                0
# 47                            exo/mobile/GX010044.MP4                1
# 48                             exo/cam01/GX010043.MP4                0
# 49                             exo/cam02/GX010062.MP4                0
#
#     is_redacted component_metadata deidentification_metadata
# 0         False               None                      None
# 1         False               None                      None
# 2         False               None                      None
# 3         False               None                      None
# 4         False               None                      None
# 5         False               None                      None
# 6         False               None                      None
# 7         False               None                      None
# 8         False               None                      None
# 9         False               None                      None
# 10        False               None                      None
# 11        False               None                      None
# 12        False               None                      None
# 13        False               None                      None
# 14        False               None                      None
# 15        False               None                      None
# 16        False               None                      None
# 17        False               None                      None
# 18        False               None                      None
# 19        False               None                      None
# 20        False               None                      None
# 21        False               None                      None
# 22        False               None                      None
# 23        False               None                      None
# 24        False               None                      None
# 25        False               None                      None
# 26        False               None                      None
# 27        False               None                      None
# 28        False               None                      None
# 29        False               None                      None
# 30        False               None                      None
# 31        False               None                      None
# 32        False               None                      None
# 33        False               None                      None
# 34        False               None                      None
# 35        False               None                      None
# 36        False               None                      None
# 37        False               None                      None
# 38        False               None                      None
# 39        False               None                      None
# 40        False               None                      None
# 41        False               None                      None
# 42        False               None                      None
# 43        False               None                      None
# 44        False               None                      None
# 45        False               None                      None
# 46        False               None                      None
# 47        False               None                      None
# 48        False               None                      None
# 49        False               None                      None

# %% [markdown]
# ## Write new manifest files to Output Directory

# %%
manifest_dir = os.path.join(OUTPUT_DIRECTORY, f"manifest_{MANIFEST_VERSION}")
file_dfs = {
    "take_metadata.csv": {
        "data": take_metadata,
        "primary_keys": ["university_take_id"]
    },
    "video_metadata.csv": {
        "data": video_metadata,
        "primary_keys": ["university_take_id", "university_video_id"]
    },
    "video_component_file.csv": {
        "data": video_component_file,
        "primary_keys": ["university_take_id", "university_video_id", "video_component_relative_path"]
    }
}

os.makedirs(manifest_dir, exist_ok = True)
for filename in file_dfs.keys():
    filepath = os.path.join(manifest_dir, filename)
    data, primary_keys = file_dfs[filename]['data'], file_dfs[filename]['primary_keys']

    # Filter out rows that already exist in this folder
    # based on the dataframe's primary keys
    if os.path.isfile(filepath):
        assert len([c for c in data.columns if c.endswith('_y') or c.endswith('_x')]) == 0, "Please rename columns ending in _x or _y"
        
        preexisting_data = pd.read_csv(filepath)
        data = pd.merge(data, preexisting_data, on=primary_keys, how="outer", indicator=True
              ).query('_merge=="left_only"')
        # Fix column names post-merge and drop merge-specific columns
        data = data.drop(columns = ['_merge'] + [c for c in data.columns if c.endswith('_y')])
        data = data.rename(columns={
            c: c[:-2]
            for c in data.columns if c.endswith('_x')
        })
        data = pd.concat([preexisting_data, data])
        print(f"Retained pre-existing data for {filename}")
    
    with open(filepath, "w") as f:
        data.to_csv(f, index=False)

print(f"Successfully wrote {len(file_dfs)} files to {manifest_dir}")
# Out:
# Retained pre-existing data for take_metadata.csv
# Retained pre-existing data for video_metadata.csv
# Retained pre-existing data for video_component_file.csv
# Successfully wrote 3 files to /Users/dkukreja/Downloads/test-manifests/manifest_v1
